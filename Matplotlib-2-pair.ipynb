# %% [markdown]
# Las preguntas que tendréis que contestar son:
#
# Ayer creamos un par de gráficas para los tickets de la categoría "Software" y "Hardware", donde visualizamos el número de clientes que teníamos en cada grupo de satisfacción. Hoy tendréis que hacer dos gráficas con subplots:
# En la primera debéis mostrar la cantidad de tickets en función del tipo (si es Problema o Solicitud), cada subplot corresponderá a cada una de las categorías. Debéis:
#
# 1. Poner nombre a los ejes de cada uno de los subplots
# 2. Poner un títulos a cada uno de los subplots
# 3. Poner el color de las líneas en negro.
# 3. Establecer el tamaño de la gráfica a 15 x 5
# 4. Ponerle marcadores a las gráficas. No incluir leyenda
#
#    - En la segunda debéis mostrar los ataques por año para cada uno de los países.
#
# 5. De nuevo tendréis que ponerle nombre a los ejes y título a cada gráfica.
# 6. En este caso el subplot deberá tener dos filas y una columna. No incluir leyenda
# 7. Cambiar el color de las barras
#
#    - Cread un único gráfico donde juntéis las gráficas de los tipos de ataques en una sola. Debéis:
#
# 8.  Poner leyenda a la gráfica
# 9.  Cada línea debe ir en un color
# 10. Ponerle nombre a los ejes y a la gráfica.
# 11. Poner marcadores a las lineas.
# 12. Guardad las figuras creadas en cada caso. Podéis usar el formato que queráis. Guarda todas las fotos en una carpeta llamada Visualizacion-II.

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
df_empleados_puestos = pd.read_csv("datos/empleados_puestos.csv")
df_empleados_puestos.head()
# Out:
#    Unnamed: 0 Turno  ID Empleado    Apellido    Nombre ID Puesto  \
# 0           0     A            6       VILLA     JESUS  50-32200
# 1           1   NaN           60        DIAZ  PATRICIA  50-32200
# 2           2     B            2      DUARTE   ANTONIO  50-32200
# 3           3   NaN           24  VILLANUEVA     JESUS  50-32200
# 4           4   NaN           98    GALLEGOS  PATRICIA  50-32200
#
#                              Email                   Puesto  \
# 0        jesus.villa@tractchun.com  Comprador de Materiales
# 1      patricia.diaz@tractchun.com  Comprador de Materiales
# 2     antonio.duarte@tractchun.com  Comprador de Materiales
# 3   jesus.villanueva@tractchun.com  Comprador de Materiales
# 4  patricia.gallegos@tractchun.com  Comprador de Materiales
#
#             Departamento     Tipo Puesto
# 0  CONTROL DE PRODUCCION  Administrativo
# 1  CONTROL DE PRODUCCION  Administrativo
# 2  CONTROL DE PRODUCCION  Administrativo
# 3  CONTROL DE PRODUCCION  Administrativo
# ...

# %%
df_historico_tickets = pd.read_csv("datos/historico_tickets.csv")
df_historico_tickets.head()
# Out:
#    Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0           0  GDDENR-5042564453  2016-07-13         1735          4
# 1           1  GDDENR-8042508060  2016-05-18         1566         10
# 2           2  GDDESR-1342539995  2016-06-18          569         29
# 3           3  GDDTSR-5942488006  2016-04-28          320         40
# 4           4  GDLEER-0042524120  2016-06-03         1842         31
#
#        categoría       tipo           severidad        prioridad  \
# 0  Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1  Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2        Sistema   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3        Sistema  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# 4       Software   Problema          2 - Normal  0 - Sin Asignar
#
#    días_resolución  satisfacción     semestre   año
# 0                0             5  2º semestre  2016
# 1                0             5   1 semestre  2016
# ...

# %%
df_ht_unicos = df_historico_tickets["tipo"].value_counts()
# Out:
# Solicitud    73138
# Problema     24248
# Name: tipo, dtype: int64

# %%
df_ht_unicos = pd.DataFrame(df_historico_tickets)

df_ht_unicos
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0               0  GDDENR-5042564453  2016-07-13         1735          4
# 1               1  GDDENR-8042508060  2016-05-18         1566         10
# 2               2  GDDESR-1342539995  2016-06-18          569         29
# 3               3  GDDTSR-5942488006  2016-04-28          320         40
# 4               4  GDLEER-0042524120  2016-06-03         1842         31
# ...           ...                ...         ...          ...        ...
# 97381       29083  TWRTSR-8543883120  2020-02-22         1142          1
# 97382       29084  TWRTSR-8744097039  2020-09-23          223         40
# 97383       29085  TWRTSR-9643846768  2020-01-16          256          7
# 97384       29086  TWRTSR-9944138906  2020-11-03         1060          9
# 97385       29087  TWRTST-8643986162  2020-06-04         1876         41
#
#            categoría       tipo           severidad        prioridad  \
# ...

# %%
df_tipo = df_historico_tickets.groupby("tipo").mean()

df_tipo
# Out:
# /var/folders/qs/lczv8kqx5w59ygqwfs1w0vlr0000gn/T/ipykernel_17027/3146714655.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_tipo = df_historico_tickets.groupby("tipo").mean()
#              Unnamed: 0  id_empleado  id_agente  días_resolución  \
# tipo
# Problema   10201.164838   997.648961  25.552293         3.110401
# Solicitud  10690.587615   999.661817  25.441193         5.030942
#
#            satisfacción          año
# tipo
# Problema       4.099225  2018.402095
# Solicitud      4.101575  2018.398192

# %%
df_ht_unicos.columns
# Out:
# Index(['Unnamed: 0', 'id_ticket', 'fecha', 'id_empleado', 'id_agente',
#        'categoría', 'tipo', 'severidad', 'prioridad', 'días_resolución',
#        'satisfacción', 'semestre', 'año'],
#       dtype='object')

# %%
df_tipo = df_ht_unicos[(df_ht_unicos["tipo"] == "Problema") | (df_ht_unicos ["tipo"] == "Solicitud")]

df_tipo
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0               0  GDDENR-5042564453  2016-07-13         1735          4
# 1               1  GDDENR-8042508060  2016-05-18         1566         10
# 2               2  GDDESR-1342539995  2016-06-18          569         29
# 3               3  GDDTSR-5942488006  2016-04-28          320         40
# 4               4  GDLEER-0042524120  2016-06-03         1842         31
# ...           ...                ...         ...          ...        ...
# 97381       29083  TWRTSR-8543883120  2020-02-22         1142          1
# 97382       29084  TWRTSR-8744097039  2020-09-23          223         40
# 97383       29085  TWRTSR-9643846768  2020-01-16          256          7
# 97384       29086  TWRTSR-9944138906  2020-11-03         1060          9
# 97385       29087  TWRTST-8643986162  2020-06-04         1876         41
#
#            categoría       tipo           severidad        prioridad  \
# ...

# %%
df_etiquetas = df_tipo.groupby("Problema")["tipo"].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df_etiquetas = df_tipo.groupby("Problema")["tipo"].count()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
fig,ax = plt.subplots(1,2)

ax[0].scatter(df_tipo["tipo"], marker = 'v', c= df_tipo['Problema'] , alpha = 0.8)
ax[1].scatter(df_tipo["tipo"], marker = 'v', c= df_tipo['Solicitud'] , alpha = 0.8)




plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Problema'
#
# ...
