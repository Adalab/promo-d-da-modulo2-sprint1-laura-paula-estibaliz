# %% [markdown]
# # Pair Programming Visualización II

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_años = pd.read_csv('../datos/años.csv', index_col=0)
df_años.head(2)
# Out:
#            id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453  2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060  2016-05-18       1566.0       10.0  Acceso&%Login
#
#        tipo           severidad        prioridad  días_resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
#
#    satisfacción   año
# 0           5.0  2016
# 1           5.0  2016

# %%
df_puestos = pd.read_csv('../datos/empleados_puestos.csv', index_col=0)
df_puestos.head(2)
# Out:
#   Turno  ID Empleado Apellido    Nombre ID Puesto  \
# 0     A            6    VILLA     JESUS  50-32200
# 1   NaN           60     DIAZ  PATRICIA  50-32200
#
#                          Email                   Puesto  \
# 0    jesus.villa@tractchun.com  Comprador de Materiales
# 1  patricia.diaz@tractchun.com  Comprador de Materiales
#
#             Departamento     Tipo Puesto
# 0  CONTROL DE PRODUCCION  Administrativo
# 1  CONTROL DE PRODUCCION  Administrativo

# %%
df_agentes = pd.read_csv('../datos/Agentes.csv', index_col=0)
df_agentes.head(2)
# Out:
#                  Nombre                        email Fecha de Nacimiento
# ID Agente
# 1           Mata Lucero    lucero.mata@tractchun.com           1989/4/28
# 2          JesusGrajeda  jesus.grajeda@tractchun.com            1979/1/1

# %% [markdown]
# Las preguntas que tendréis que contestar son:
#
# 1. Ayer creamos un par de gráficas para los tickets de la categoría "Software" y "Hardware", donde visualizamos el número de clientes que teníamos en cada grupo de satisfacción. Hoy tendréis que hacer dos gráficas con subplots:

# %%
df_sw_hw = df_años[(df_años["categoría"] == "Hardware") | (df_años["categoría"] == "Software")]
df_sw_hw.head(2)
# Out:
#            id_ticket       fecha  id_empleado  id_agente categoría      tipo  \
# 4  GDLEER-0042524120  2016-06-03       1842.0       31.0  Software  Problema
# 5  GDLEER-0142608095  2016-08-26         59.0       20.0  Software  Problema
#
#     severidad        prioridad  días_resolución  satisfacción   año
# 4  2 - Normal  0 - Sin Asignar              0.0           5.0  2016
# 5  2 - Normal  0 - Sin Asignar              1.0           1.0  2016

# %%
df_tipo_hw = df_sw_hw[df_sw_hw["categoría"] == "Hardware"]
df_valores_tipo_hw = df_tipo_hw["tipo"].value_counts().reset_index()
df_valores_tipo_hw
# Out:
#        index  tipo
# 0  Solicitud  7368
# 1   Problema  2364

# %%
df_tipo_sw = df_sw_hw[df_sw_hw["categoría"] == "Software"]
df_valores_tipo_sw = df_tipo_sw["tipo"].value_counts().reset_index()
df_valores_tipo_sw
# Out:
#        index   tipo
# 0  Solicitud  14634
# 1   Problema   4931

# %% [markdown]
# En la primera debéis mostrar la cantidad de tickets en función del tipo (si es Problema o Solicitud), cada subplot corresponderá a cada una de las categorías.
#
# Debéis:
#
# - Poner nombre a los ejes de cada uno de los subplots
# - Poner un títulos a cada uno de los subplots
# - Poner el color de las líneas en negro.
# - Establecer el tamaño de la gráfica a 15 x 5
# - Ponerle marcadores a las gráficas
# - No incluir leyenda

# %%
fig, ax = plt.subplots(1,2, figsize = (15,5))

ax[0].plot(df_valores_tipo_hw["index"], df_valores_tipo_hw["tipo"], marker = "*", color = "black")
ax[1].plot(df_valores_tipo_sw["index"], df_valores_tipo_sw["tipo"], marker = "x", color = "black")

ax[0].set_xlabel("tipo")
ax[1].set_xlabel("tipo")
ax[0].set_ylabel("Nº tickets")
ax[1].set_ylabel("Nº tickets")

ax[0].set_title("Hardware")
ax[1].set_title("Software")

plt.show()

# %% [markdown]
# En la segunda debéis mostrar el número de tickets en función de la satisfacción.

# %%
df_tipo_hw = df_sw_hw[df_sw_hw["categoría"] == "Hardware"]
df_valores_hw = df_tipo_hw["satisfacción"].value_counts().reset_index()
df_valores_hw
# Out:
#    index  satisfacción
# 0    5.0          5106
# 1    4.0          2691
# 2    1.0          1003
# 3    3.0           745
# 4    2.0           185

# %%
df_tipo_sw = df_sw_hw[df_sw_hw["categoría"] == "Software"]
df_valores_sw = df_tipo_sw["satisfacción"].value_counts().reset_index()
df_valores_sw
# Out:
#    index  satisfacción
# 0    5.0         10240
# 1    4.0          5494
# 2    1.0          1972
# 3    3.0          1468
# 4    2.0           388

# %% [markdown]
# De nuevo tendréis que ponerle nombre a los ejes y título a cada gráfica.
# - En este caso el subplot deberá tener dos filas y una columna
# - No incluir leyenda
# - Cambiar el color de las barras

# %%
fig, ax = plt.subplots(2,1, figsize = (15,10))

ax[0].bar(df_valores_hw["index"], df_valores_hw["satisfacción"], edgecolor = "black", facecolor = "violet")
ax[1].bar(df_valores_sw["index"], df_valores_sw["satisfacción"], edgecolor = "black", facecolor = "pink")

ax[0].set_xlabel("satisfacción")
ax[1].set_xlabel("satisfacción")
ax[0].set_ylabel("Nº tickets")
ax[1].set_ylabel("Nº tickets")

ax[0].set_title("Hardware")
ax[1].set_title("Software")

plt.show()

# %% [markdown]
# Cread un subplot con dos gráficas, dónde en la primera tengamos el número de empleados por departamento y en la otra por tipo de puesto.
#
# Debéis:
#
# - Poner leyenda a la gráfica
# - Cada línea debe ir en un color
# - Ponerle nombre a los ejes y a la gráfica.
# - Poner marcadores a las lineas.

# %%
df_1 = df_emp_pues["Departamento"].value_counts().reset_index()
df_1
# Out:
#                                           index  Departamento
# 0                                    PRODUCCION           475
# 1                         INGENIERIA DE CALIDAD           395
# 2                                 MANTENIMIENTO           258
# 3                     INGENIERIA DE MANUFACTURA           228
# 4                   SISTEMAS, TRAFICO Y ADUANAS           160
# 5                         CONTROL DE PRODUCCION           127
# 6                                    MATERIALES           125
# 7                              Recursos Humanos           117
# 8   AUDITORIA INTERNA, CALIBRACION Y METROLOGIA            70
# 9                                  CONTABILIDAD            25
# 10                                     PERSONAL            20

# %%
df_2 = df_emp_pues["Puesto"].value_counts().reset_index()
df_2
# Out:
#                                       index  Puesto
# 0                  Supervisor de Producción     458
# 1                  Ingeniero de Manufactura     213
# 2    Supervisor de Aseguramiento de Calidad     186
# 3                      Ingeniero de Calidad     162
# 4                     Ingeniero de Procesos      96
# ..                                      ...     ...
# 59                               Maquinista       2
# 60                    Supervisor de captura       1
# 61  Secretaria de Ingeniería de Manufactura       1
# 62                     Planeador de Compras       1
# 63   Supervisor General de Aseg. de Calidad       1
#
# [64 rows x 2 columns]

# %%
fig, ax = plt.subplots(1,2, figsize = (20,10))

ax[0].plot(df_1["index"], df_1["Departamento"], label= 'Nº empleados por departamento', marker= "+", color = "blue")
ax[1].plot(df_2["index"], df_2["Puesto"], label= 'Nº empleados por departamento', marker= "*", color = "grey")

ax[0].set_xlabel("Departamento")
ax[1].set_xlabel("Puesto")
ax[0].set_ylabel("Nº empleados")
ax[1].set_ylabel("Nº empleados")

ax[0].set_xticklabels(labels = df_1["index"], rotation="vertical")
ax[1].set_xticklabels(labels = df_2["index"], rotation="vertical")

ax[0].set_title("Empleados/departamento")
ax[1].set_title("Empleados/puesto")

ax[0].legend()
ax[1].legend()

plt.show()
# Out:
# /tmp/ipykernel_334/3575175023.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(labels = df_1["index"], rotation="vertical")
# /tmp/ipykernel_334/3575175023.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels(labels = df_2["index"], rotation="vertical")

# %% [markdown]
# Guardad las figuras creadas en cada caso. Podéis usar el formato que queráis. Guarda todas las fotos en una carpeta llamada Visualizacion-II.
