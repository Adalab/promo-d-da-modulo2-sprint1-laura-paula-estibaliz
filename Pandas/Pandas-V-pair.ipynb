# %% [markdown]
# ### En este ejercicio pondremos en práctica los conceptos básicos para juntar varios csv que compartan información.  - En pairs anteriores habíamos explorado algunos conjuntos de datos, estos conjuntos de datos eran:###
#
#
# - El csv que creamos en el ejercicio de pair programming Pandas IV, dónde recordamos eliminamos ciertas columnas que no eran necesarias, y habíamos creado nuevas.
# - El csv llamado Empleados donde tenemos información sobre los empleados de la empresa, este fichero lo tenéis un poco mas abajo para descargar.
# - El csv llamado Puestos donde tenemos información sobre los puestos que hay en la empresa y que departamento pertencen.
# - El csv llamado Agentes donde tenemos información sobre los puestos que hay en la empresa y que departamento pertencen.
#
# El principal objetivo de este ejercicio de pair programming es acabar teniendo un único DataFrame con toda la información contenida en los tres csv anteriores.

# %%
import pandas as pd

# %%
df_2016 = pd.read_excel("../datos/2016_pandasIII.xlsx")
df_2016.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción
# 0           5.0
# 1           5.0
# 2           5.0
# 3           5.0
# 4           5.0

# %%
df_2017 = pd.read_excel("../datos/2017.xlsx")
df_2017.head()
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente Categoría      Tipo  \
# 0  GDDEER-8142900901 2017-06-14       1200.0       29.0  Software  Problema
# 1  GDDEST-7342745152 2017-01-10       1855.0       31.0   Sistema  Problema
# 2  GDLEER-0042906431 2017-06-20        233.0       34.0  Software  Problema
# 3  GDLEER-0042997167 2017-09-19        996.0       21.0  Software  Problema
# 4  GDLEER-0142746832 2017-01-11       1113.0       48.0  Software  Problema
#
#             Severidad        Prioridad  Días Resolución  Satisfacción
# 0  0 - Sin Clasificar  0 - Sin Asignar              1.0           5.0
# 1  0 - Sin Clasificar  0 - Sin Asignar              3.0           5.0
# 2          2 - Normal  0 - Sin Asignar              0.0           5.0
# 3          2 - Normal  0 - Sin Asignar              0.0           5.0
# 4          2 - Normal  0 - Sin Asignar              1.0           5.0

# %%
df_2018 = pd.read_excel("../datos/2018.xlsx")
df_2018.head()
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0  GDDEER-9743106195 2018-01-06        759.0       21.0       Hardware
# 1  GDDENR-9043229214 2018-05-09        521.0        2.0  Acceso-&Login
# 2  GDDENT-9043303547 2018-07-22       1564.0       45.0  Acceso-&Login
# 3  GDDESR-1243421724 2018-11-17         32.0       27.0        Sistema
# 4  GDDESR-8843106588 2018-01-06       1928.0       45.0        Sistema
#
#        Tipo           Severidad        Prioridad  Días Resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              7.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 3  Problema  0 - Sin Clasificar  0 - Sin Asignar              2.0
# 4  Problema  0 - Sin Clasificar  0 - Sin Asignar              8.0
#
#    Satisfacción
# 0           5.0
# 1           5.0
# 2           1.0
# 3           5.0
# 4           5.0

# %%
df_2019 = pd.read_excel("../datos/2019.xlsx")
df_2019.head()
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0  GDDEER-5743562837 2019-04-07       1833.0       48.0       Hardware
# 1  GDDEER-6043685286 2019-08-08        528.0       32.0       Hardware
# 2  GDDEET-7743705549 2019-08-28        654.0       45.0       Hardware
# 3  GDDENR-1043755533 2019-10-17        243.0       15.0  Acceso99Login
# 4  GDDESR-9243800417 2019-12-01        601.0       34.0        Sistema
#
#        Tipo           Severidad        Prioridad  Días Resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              7.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar             10.0
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar              7.0
# 3  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 4  Problema  0 - Sin Clasificar  0 - Sin Asignar              2.0
#
#    Satisfacción
# 0           5.0
# 1           5.0
# 2           1.0
# 3           5.0
# 4           5.0

# %%
df_2020 = pd.read_excel("../datos/2020.xlsx")
df_2020.head()
# Out:
#            ID Ticket      Fecha      Tipo     Categoría  ID Empleado  \
# 0  GDDENR-6044135832 2020-10-31  Problema  Acceso/Login        773.0
# 1  GDDESR-1444031730 2020-07-19  Problema       Sistema        613.0
# 2  GDDESR-3244128887 2020-10-24  Problema       Sistema       1508.0
# 3  GDDESR-4443972026 2020-05-21  Problema       Sistema       1192.0
# 4  GDDESR-9044014744 2020-07-02  Problema       Sistema       1224.0
#
#    ID Agente           Severidad        Prioridad  Días Resolución  \
# 0       48.0  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1       17.0  0 - Sin Clasificar  0 - Sin Asignar              4.0
# 2        8.0  0 - Sin Clasificar  0 - Sin Asignar              2.0
# 3       20.0  0 - Sin Clasificar  0 - Sin Asignar              4.0
# 4        7.0  0 - Sin Clasificar  0 - Sin Asignar             10.0
#
#    Satisfacción
# 0           5.0
# 1           5.0
# 2           1.0
# 3           5.0
# 4           5.0

# %%
df_puestos = pd.read_excel("../datos/Puestos.xlsx")
df_puestos.head()
# Out:
#   ID Puesto                            Puesto Departamento     Tipo Puesto
# 0  10-23200           Ingeniero de Materiales   MATERIALES       Operativo
# 1  10-24111            Operador de Producción   MATERIALES       Operativo
# 2  10-25120               Auxiliar de compras   MATERIALES  Administrativo
# 3  10-25130                         Comprador   MATERIALES  Administrativo
# 4  10-32050  Supervisor General de Materiales   MATERIALES   Mandos Medios

# %%
df_agentes = pd.read_csv("../datos/Agentes.csv")
df_agentes.head()
# Out:
#    ID Agente               Nombre                              email  \
# 0          1          Mata Lucero          lucero.mata@tractchun.com
# 1          2         JesusGrajeda        jesus.grajeda@tractchun.com
# 2          3          Elena Velez          elena.velez@tractchun.com
# 3          4      Barraza Alberto      alberto.barraza@tractchun.com
# 4          5  Willyberto Gonzales  willyberto.gonzales@tractchun.com
#
#   Fecha de Nacimiento
# 0           1989/4/28
# 1            1979/1/1
# 2            1993/6/6
# 3          1978/10/20
# 4           1973/5/11

# %%
df_empleados = pd.read_csv("../datos/Empleados2.csv")
df_empleados.head()
# Out:
#   Turno  ID Empleado Apellido     Nombre ID Puesto  \
# 0     A            6    VILLA      JESUS  50-32200
# 1   NaN           10   MENDEZ    RICARDO  15-24100
# 2   NaN           21  HEREDIA  GUADALUPE  90-14000
# 3   NaN           27    DURAN    DESSENS  15-24100
# 4   NaN           29   LAGUNA   FEDERICO  80-24100
#
#                              Email
# 0        jesus.villa@tractchun.com
# 1     ricardo.mendez@tractchun.com
# 2  guadalupe.heredia@tractchun.com
# 3      dessens.duran@tractchun.com
# 4    federico.laguna@tractchun.com

# %% [markdown]
# - Antes de empezar, deberéis crear una columna nueva en los dataframes de 2016.xlsx, 2017.xlsx, 2018.xlsx, 2019.xlsx, 2020.xlsx que contenga los valores del año al que corresponden.
#
# - Para llevar a cabo nuestro objetivo tendréis que seguir los siguientes pasos:

# %%
df_2016["año"] = ("2016")

df_2016.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción   año
# 0           5.0  2016
# 1           5.0  2016
# 2           5.0  2016
# 3           5.0  2016
# 4           5.0  2016

# %%
df_2017["año"] = ("2017")

df_2017.head()
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente Categoría      Tipo  \
# 0  GDDEER-8142900901 2017-06-14       1200.0       29.0  Software  Problema
# 1  GDDEST-7342745152 2017-01-10       1855.0       31.0   Sistema  Problema
# 2  GDLEER-0042906431 2017-06-20        233.0       34.0  Software  Problema
# 3  GDLEER-0042997167 2017-09-19        996.0       21.0  Software  Problema
# 4  GDLEER-0142746832 2017-01-11       1113.0       48.0  Software  Problema
#
#             Severidad        Prioridad  Días Resolución  Satisfacción   año
# 0  0 - Sin Clasificar  0 - Sin Asignar              1.0           5.0  2017
# 1  0 - Sin Clasificar  0 - Sin Asignar              3.0           5.0  2017
# 2          2 - Normal  0 - Sin Asignar              0.0           5.0  2017
# 3          2 - Normal  0 - Sin Asignar              0.0           5.0  2017
# 4          2 - Normal  0 - Sin Asignar              1.0           5.0  2017

# %%
df_2018["año"] = ("2018")

df_2018.head()
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0  GDDEER-9743106195 2018-01-06        759.0       21.0       Hardware
# 1  GDDENR-9043229214 2018-05-09        521.0        2.0  Acceso-&Login
# 2  GDDENT-9043303547 2018-07-22       1564.0       45.0  Acceso-&Login
# 3  GDDESR-1243421724 2018-11-17         32.0       27.0        Sistema
# 4  GDDESR-8843106588 2018-01-06       1928.0       45.0        Sistema
#
#        Tipo           Severidad        Prioridad  Días Resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              7.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 3  Problema  0 - Sin Clasificar  0 - Sin Asignar              2.0
# 4  Problema  0 - Sin Clasificar  0 - Sin Asignar              8.0
#
#    Satisfacción   año
# 0           5.0  2018
# 1           5.0  2018
# 2           1.0  2018
# 3           5.0  2018
# 4           5.0  2018

# %%
df_2019["año"] = ("2019")

df_2019.head()
# Out:
#            ID Ticket      Fecha  ID Empleado  ID Agente      Categoría  \
# 0  GDDEER-5743562837 2019-04-07       1833.0       48.0       Hardware
# 1  GDDEER-6043685286 2019-08-08        528.0       32.0       Hardware
# 2  GDDEET-7743705549 2019-08-28        654.0       45.0       Hardware
# 3  GDDENR-1043755533 2019-10-17        243.0       15.0  Acceso99Login
# 4  GDDESR-9243800417 2019-12-01        601.0       34.0        Sistema
#
#        Tipo           Severidad        Prioridad  Días Resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              7.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar             10.0
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar              7.0
# 3  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 4  Problema  0 - Sin Clasificar  0 - Sin Asignar              2.0
#
#    Satisfacción   año
# 0           5.0  2019
# 1           5.0  2019
# 2           1.0  2019
# 3           5.0  2019
# 4           5.0  2019

# %%
df_2020["año"] = ("2020")

df_2020.head()
# Out:
#            ID Ticket      Fecha      Tipo     Categoría  ID Empleado  \
# 0  GDDENR-6044135832 2020-10-31  Problema  Acceso/Login        773.0
# 1  GDDESR-1444031730 2020-07-19  Problema       Sistema        613.0
# 2  GDDESR-3244128887 2020-10-24  Problema       Sistema       1508.0
# 3  GDDESR-4443972026 2020-05-21  Problema       Sistema       1192.0
# 4  GDDESR-9044014744 2020-07-02  Problema       Sistema       1224.0
#
#    ID Agente           Severidad        Prioridad  Días Resolución  \
# 0       48.0  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1       17.0  0 - Sin Clasificar  0 - Sin Asignar              4.0
# 2        8.0  0 - Sin Clasificar  0 - Sin Asignar              2.0
# 3       20.0  0 - Sin Clasificar  0 - Sin Asignar              4.0
# 4        7.0  0 - Sin Clasificar  0 - Sin Asignar             10.0
#
#    Satisfacción   año
# 0           5.0  2020
# 1           5.0  2020
# 2           1.0  2020
# 3           5.0  2020
# 4           5.0  2020

# %% [markdown]
# 1. Cargad los siete ficheros nombrados anteriormente y los exploramos para familizarizarnos con ellos y saber que información tienen en común y debatir entre vosotras como podríamos juntar toda la información.
#
# 2. Chequead que los nombres de las columnas y ver si se llaman iguales entre dataframes. ¿Están todas en minúsculas? ¿Tienen espacios? En caso de que no sea así homogeneizar los nombres de las columnas para que todos los dataframes tengan el mismo formato.

# %% [markdown]
# - Hemos revisado las columnas y los datos en general que tenemos y hemos visto que las columnas tienen mayúsculas y espacios que vamos a reemplazar con una funcion.

# %%
def cambio_columnas(df):
    cols = {col: col.replace(" ", "_").lower() for col in df.columns}
    df.rename(columns=cols, inplace=True)
    display(df.head())

# %%
cambio_columnas(df_2017)
cambio_columnas(df_2018)
cambio_columnas(df_2019)
cambio_columnas(df_2020)
cambio_columnas(df_puestos)
cambio_columnas(df_empleados)
cambio_columnas(df_agentes)
# Out:
#            id_ticket      fecha  id_empleado  id_agente categoría      tipo  \
# 0  GDDEER-8142900901 2017-06-14       1200.0       29.0  Software  Problema
# 1  GDDEST-7342745152 2017-01-10       1855.0       31.0   Sistema  Problema
# 2  GDLEER-0042906431 2017-06-20        233.0       34.0  Software  Problema
# 3  GDLEER-0042997167 2017-09-19        996.0       21.0  Software  Problema
# 4  GDLEER-0142746832 2017-01-11       1113.0       48.0  Software  Problema
#
#             severidad        prioridad  días_resolución  satisfacción   año
# 0  0 - Sin Clasificar  0 - Sin Asignar              1.0           5.0  2017
# 1  0 - Sin Clasificar  0 - Sin Asignar              3.0           5.0  2017
# 2          2 - Normal  0 - Sin Asignar              0.0           5.0  2017
# 3          2 - Normal  0 - Sin Asignar              0.0           5.0  2017
# 4          2 - Normal  0 - Sin Asignar              1.0           5.0  2017
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDEER-9743106195 2018-01-06        759.0       21.0       Hardware
# 1  GDDENR-9043229214 2018-05-09        521.0        2.0  Acceso-&Login
# 2  GDDENT-9043303547 2018-07-22       1564.0       45.0  Acceso-&Login
# 3  GDDESR-1243421724 2018-11-17         32.0       27.0        Sistema
# 4  GDDESR-8843106588 2018-01-06       1928.0       45.0        Sistema
#
#        tipo           severidad        prioridad  días_resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              7.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 3  Problema  0 - Sin Clasificar  0 - Sin Asignar              2.0
# 4  Problema  0 - Sin Clasificar  0 - Sin Asignar              8.0
#
#    satisfacción   año
# 0           5.0  2018
# 1           5.0  2018
# 2           1.0  2018
# 3           5.0  2018
# 4           5.0  2018
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDEER-5743562837 2019-04-07       1833.0       48.0       Hardware
# 1  GDDEER-6043685286 2019-08-08        528.0       32.0       Hardware
# 2  GDDEET-7743705549 2019-08-28        654.0       45.0       Hardware
# 3  GDDENR-1043755533 2019-10-17        243.0       15.0  Acceso99Login
# 4  GDDESR-9243800417 2019-12-01        601.0       34.0        Sistema
#
#        tipo           severidad        prioridad  días_resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              7.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar             10.0
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar              7.0
# 3  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 4  Problema  0 - Sin Clasificar  0 - Sin Asignar              2.0
#
#    satisfacción   año
# 0           5.0  2019
# 1           5.0  2019
# 2           1.0  2019
# 3           5.0  2019
# 4           5.0  2019
#            id_ticket      fecha      tipo     categoría  id_empleado  \
# 0  GDDENR-6044135832 2020-10-31  Problema  Acceso/Login        773.0
# 1  GDDESR-1444031730 2020-07-19  Problema       Sistema        613.0
# 2  GDDESR-3244128887 2020-10-24  Problema       Sistema       1508.0
# 3  GDDESR-4443972026 2020-05-21  Problema       Sistema       1192.0
# 4  GDDESR-9044014744 2020-07-02  Problema       Sistema       1224.0
#
#    id_agente           severidad        prioridad  días_resolución  \
# 0       48.0  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1       17.0  0 - Sin Clasificar  0 - Sin Asignar              4.0
# 2        8.0  0 - Sin Clasificar  0 - Sin Asignar              2.0
# 3       20.0  0 - Sin Clasificar  0 - Sin Asignar              4.0
# 4        7.0  0 - Sin Clasificar  0 - Sin Asignar             10.0
#
#    satisfacción   año
# 0           5.0  2020
# 1           5.0  2020
# 2           1.0  2020
# 3           5.0  2020
# 4           5.0  2020
#   id_puesto                            puesto departamento     tipo_puesto
# 0  10-23200           Ingeniero de Materiales   MATERIALES       Operativo
# 1  10-24111            Operador de Producción   MATERIALES       Operativo
# 2  10-25120               Auxiliar de compras   MATERIALES  Administrativo
# 3  10-25130                         Comprador   MATERIALES  Administrativo
# 4  10-32050  Supervisor General de Materiales   MATERIALES   Mandos Medios
#   turno  id_empleado apellido     nombre id_puesto  \
# 0     A            6    VILLA      JESUS  50-32200
# 1   NaN           10   MENDEZ    RICARDO  15-24100
# 2   NaN           21  HEREDIA  GUADALUPE  90-14000
# 3   NaN           27    DURAN    DESSENS  15-24100
# 4   NaN           29   LAGUNA   FEDERICO  80-24100
#
#                              email
# 0        jesus.villa@tractchun.com
# 1     ricardo.mendez@tractchun.com
# 2  guadalupe.heredia@tractchun.com
# 3      dessens.duran@tractchun.com
# 4    federico.laguna@tractchun.com
#    id_agente               nombre                              email  \
# 0          1          Mata Lucero          lucero.mata@tractchun.com
# 1          2         JesusGrajeda        jesus.grajeda@tractchun.com
# 2          3          Elena Velez          elena.velez@tractchun.com
# 3          4      Barraza Alberto      alberto.barraza@tractchun.com
# 4          5  Willyberto Gonzales  willyberto.gonzales@tractchun.com
#
#   fecha_de_nacimiento
# 0           1989/4/28
# 1            1979/1/1
# 2            1993/6/6
# 3          1978/10/20
# 4           1973/5/11

# %% [markdown]
# 3. En este momento nos habremos dado cuenta que el DataFrame que generamos en el pair programming Pandas IV es similar al DataFrame de los datos históricos (2017.xlsx, 2018.xlsx, 2019.xlsx, 2020.xlsx). Si recordamos, eliminamos algunas columnas en la sesión III que no eran útiles, tendréis que ver si esas columnas están en los dataframes nuevos, si es así eliminarlas. Por lo tanto, realizad los cambios que creáis necesarios para que los dataframes sean iguales y luego juntadlos usando el mejor método.

# %% [markdown]
# - Las columnas 'web' e 'indice' son las que había que eliminar.

# %% [markdown]
# 4. Es el momento de unir la información de todos los puestos y los empleados. Debatid que método es el más correcto para unir toda esta información y ejecutadlo.

# %%
df_puestos.head()
# Out:
#   id_puesto                            puesto departamento     tipo_puesto
# 0  10-23200           Ingeniero de Materiales   MATERIALES       Operativo
# 1  10-24111            Operador de Producción   MATERIALES       Operativo
# 2  10-25120               Auxiliar de compras   MATERIALES  Administrativo
# 3  10-25130                         Comprador   MATERIALES  Administrativo
# 4  10-32050  Supervisor General de Materiales   MATERIALES   Mandos Medios

# %%
df_empleados.head()
# Out:
#   turno  id_empleado apellido     nombre id_puesto  \
# 0     A            6    VILLA      JESUS  50-32200
# 1   NaN           10   MENDEZ    RICARDO  15-24100
# 2   NaN           21  HEREDIA  GUADALUPE  90-14000
# 3   NaN           27    DURAN    DESSENS  15-24100
# 4   NaN           29   LAGUNA   FEDERICO  80-24100
#
#                              email
# 0        jesus.villa@tractchun.com
# 1     ricardo.mendez@tractchun.com
# 2  guadalupe.heredia@tractchun.com
# 3      dessens.duran@tractchun.com
# 4    federico.laguna@tractchun.com

# %%
df_puestos_empleados = df_puestos.merge(df_empleados, on='id_puesto')
df_puestos_empleados.sample(10)
# Out:
#      id_puesto                                  puesto  \
# 872   45-11000  Supervisor de Aseguramiento de Calidad
# 1595  80-22210             Supervisor de Mantenimiento
# 480   15-24100                Supervisor de Producción
# 630   20-31210                              Capturista
# 1777  80-24100                Supervisor de Producción
# 898   45-11000  Supervisor de Aseguramiento de Calidad
# 942   45-11000  Supervisor de Aseguramiento de Calidad
# 1506  70-21120            Auxiliar de Recursos Humanos
# 982   45-11000  Supervisor de Aseguramiento de Calidad
# 526   15-24100                Supervisor de Producción
#
#                      departamento     tipo_puesto turno  id_empleado  \
# 872         INGENIERIA DE CALIDAD   Mandos Medios   NaN          573
# 1595                MANTENIMIENTO   Mandos Medios   NaN          520
# 480                    PRODUCCION   Mandos Medios   NaN         1716
# 630   SISTEMAS, TRAFICO Y ADUANAS  Administrativo   NaN         1737
# 1777                MANTENIMIENTO   Mandos Medios   NaN           19
# 898         INGENIERIA DE CALIDAD   Mandos Medios   NaN           40
# 942         INGENIERIA DE CALIDAD   Mandos Medios   NaN          495
# 1506             Recursos Humanos  Administrativo   NaN          140
# 982         INGENIERIA DE CALIDAD   Mandos Medios   NaN          657
# 526                    PRODUCCION   Mandos Medios   NaN         1986
#
#        apellido     nombre                            email
# 872        SOTO     MARINA        marina.soto@tractchun.com
# 1595    GALLEGO  GUADALUPE  guadalupe.gallego@tractchun.com
# 480    FIGUEROA   LAURIANO  lauriano.figueroa@tractchun.com
# 630     BORQUEZ    LETICIA    leticia.borquez@tractchun.com
# 1777     BURBOA     MANUEL      manuel.burboa@tractchun.com
# 898     THOMSON    OCTAVIO    octavio.thomson@tractchun.com
# 942   Echeverry    Marcela  marcela.echeverry@tractchun.com
# 1506       Soto  Margarita     margarita.soto@tractchun.com
# 982     Montoya   Fernando   fernando.montoya@tractchun.com
# 526     NEVAREZ      AIDEE      aidee.nevarez@tractchun.com

# %%
# hacemos un concta para los xlsx de los años.

df_años = pd.concat([df_2016, df_2017, df_2018, df_2019, df_2020], axis=0)
df_años.sample(10)
# Out:
#                id_ticket      fecha  id_empleado  id_agente      categoría  \
# 5546   GHLTST-7643894473 2020-03-04       1157.0       34.0        Sistema
# 2923   GHLTET-7343537012 2019-03-13        981.0       10.0       Software
# 5242   GHLTSR-8643933277 2020-04-12        177.0        2.0        Sistema
# 16079  KWLTNR-4043903745 2020-03-13       1944.0       47.0   Acceso/Login
# 2581   GHLTSR-6743014522 2017-10-06       1772.0       45.0        Sistema
# 13165  KHLTSR-2743945780 2020-04-24        758.0       17.0        Sistema
# 10268  KWLENR-9243418673 2018-11-14        687.0       46.0  Acceso-&Login
# 8366   KHLEER-8743599717 2019-05-14        601.0       17.0       Hardware
# 10968  TDLTNR-7042627468 2016-09-14       1576.0       14.0  Acceso&%Login
# 1737   GDRTNR-7043301794 2018-07-20       1139.0       27.0  Acceso-&Login
#
#             tipo   severidad        prioridad  días_resolución  satisfacción  \
# 5546   Solicitud  2 - Normal         3 - Alta              6.0           5.0
# 2923   Solicitud  2 - Normal         3 - Alta              3.0           5.0
# 5242   Solicitud  2 - Normal         3 - Alta              6.0           5.0
# 16079  Solicitud  2 - Normal         1 - Baja              0.0           4.0
# 2581   Solicitud  2 - Normal         3 - Alta              7.0           5.0
# 13165  Solicitud  2 - Normal         3 - Alta              7.0           4.0
# 10268   Problema  2 - Normal         1 - Baja              2.0           1.0
# 8366    Problema  2 - Normal         3 - Alta              7.0           4.0
# 10968  Solicitud  2 - Normal  0 - Sin Asignar              0.0           5.0
# 1737   Solicitud   3 - Mayor  0 - Sin Asignar              0.0           5.0
#
#         año
# 5546   2020
# 2923   2019
# 5242   2020
# 16079  2020
# 2581   2017
# 13165  2020
# 10268  2018
# 8366   2019
# 10968  2016
# 1737   2018

# %% [markdown]
# 5. Guardad los dataframes en dos csv diferentes que usaremos mañana en la clase de pair programming

# %%
# guardamos los ficheros

df_puestos_empleados.to_csv("../datos/puestos_empleados.csv")

df_años.to_csv("../datos/años.csv")

# %% [markdown]
#
#
# 📌 NOTA Al final de este pair programing deberéis tener tres ficheros:
# - El fichero de la unión de todos los conjuntos de datos de los distintos años
# - El fichero con la unión de los datos de puestos y empleados.
# - El fichero de los agentes.
