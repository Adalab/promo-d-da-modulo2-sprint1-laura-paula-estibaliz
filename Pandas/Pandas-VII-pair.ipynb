# %% [markdown]
# # Pair Programming Pandas VII
#
# # Apply

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# Seguiremos trabajando con mismos csv que en el pair anterior, el de los empleados que unimos en el pair de unión de datasets y el de los tickets de todos los años.
#
# 3. En el pair programming desde a dirección nos pedían que agruparamos los datos en base a la columna de "categoría", puede que en aquel momento nos dieramos cuenta que había varías categorías que eran igual (en concreto "Acceso Login") pero que en algunos casos tenía unos símbolos raros (&, %, -). Es el momento de limpiar esta columna. El objetivo, reemplazar todos estos símbolos raros por "/", para conseguir homogeneizar los valores de esta columna. Para ellos deberemos crear una función.
#
# 4. Una vez que hayáis terminado eliminad las columnas originales conservando las nuevas.
#
# 5. Guardad el dataframe en un csv que usaremos más adelante

# %%
df_puestos = pd.read_csv("../datos/puestos_empleados.csv", index_col=0)
df_puestos.head()
# Out:
#   id_puesto                   puesto departamento tipo_puesto turno  \
# 0  10-23200  Ingeniero de Materiales   MATERIALES   Operativo   NaN
# 1  10-23200  Ingeniero de Materiales   MATERIALES   Operativo   NaN
# 2  10-23200  Ingeniero de Materiales   MATERIALES   Operativo   NaN
# 3  10-24111   Operador de Producción   MATERIALES   Operativo   NaN
# 4  10-24111   Operador de Producción   MATERIALES   Operativo   NaN
#
#    id_empleado    apellido    nombre                             email
# 0          725       Villa   Eliana        eliana .villa@tractchun.com
# 1          747      CHAVEZ  FEDERICO     federico.chavez@tractchun.com
# 2          544    FIGUEROA     ANGEL      angel.figueroa@tractchun.com
# 3         1376  Piedrahita   Gonzalo  gonzalo.piedrahita@tractchun.com
# 4           44    González   Gonzalo    gonzalo.gonzález@tractchun.com

# %%
df_historico = pd.read_csv("../datos/historico_tickets.csv", index_col=0)
df_historico.head()
# Out:
#            id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453  2016-07-13         1735          4  Acceso&%Login
# 1  GDDENR-8042508060  2016-05-18         1566         10  Acceso&%Login
# 2  GDDESR-1342539995  2016-06-18          569         29        Sistema
# 3  GDDTSR-5942488006  2016-04-28          320         40        Sistema
# 4  GDLEER-0042524120  2016-06-03         1842         31       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar                0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar                0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar                3
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar                9
# 4   Problema          2 - Normal  0 - Sin Asignar                0
#
#    satisfacción     semestre   año
# 0             5  2º semestre  2016
# 1             5   1 semestre  2016
# 2             5   1 semestre  2016
# 3             5   1 semestre  2016
# 4             5   1 semestre  2016

# %% [markdown]
# 1. Cread una columna nueva y una función que nos de el mes en el que se solicitó el servicio. Tened en cuenta que todas las filas tienen la misma estructura. A la hora de escribir la función debemos tener en cuenta que puede que no haya la información de mes en la columna de la fecha. En ese caso devolved un nulo (NaN).
#
# 📌 Nota La fecha tendrá que ir formato de string como "Enero", "Febrero", etc.
#
# 💡 Pista 💡Podréis usar regex, pero no es estrictamente necesario.

# %%
# hacemos una copia del dataframe
df_copia_historico = df_historico.copy()
df_copia_historico.head(2)
# Out:
#            id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453  2016-07-13         1735          4  Acceso&%Login
# 1  GDDENR-8042508060  2016-05-18         1566         10  Acceso&%Login
#
#        tipo           severidad        prioridad  días_resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar                0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar                0
#
#    satisfacción     semestre   año
# 0             5  2º semestre  2016
# 1             5   1 semestre  2016

# %%
# def sacar_mes(fecha):
#     return fecha.split("-")[1]

# %%
# hemos comprobado si hay valores nulos
# df_copia_historico.isnull().sum()
# Out:
# id_ticket          0
# fecha              0
# id_empleado        0
# id_agente          0
# categoría          0
# tipo               0
# severidad          0
# prioridad          0
# días_resolución    0
# satisfacción       0
# semestre           0
# año                0
# dtype: int64

# %%
df_copia_historico["mes"] = df_copia_historico["fecha"].apply(pd.to_datetime).dt.month_name()
df_copia_historico.head(1)
# Out:
#            id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453  2016-07-13         1735          4  Acceso&%Login
#
#        tipo           severidad        prioridad  días_resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar                0
#
#    satisfacción     semestre   año   mes
# 0             5  2º semestre  2016  July

# %% [markdown]
# 2. En la tabla de empleados, tenemos los nombres y los apellidos de los empleados, pero en columnas separadas. En los ejercicios de pair de la lección del groupby vimos que si quisieramos agrupar por los nombres, esto se nos puede complicar. Ahora nos piden que creemos una columna donde tengamos el nombre y el apellido juntos.
#
# 📌 NOTA La columna nueva debe tener el nombre y apellido con la primera letra en mayúsculas, por ejemplo "Jesús Villa".
#
# 📌 NOTA Una vez hallamos creado la columna nueva, eliminad las columnas de nombre y apellido originales.

# %%
df_copia_puestos = df_puestos.copy()
df_copia_puestos.head()
# Out:
#   id_puesto                   puesto departamento tipo_puesto turno  \
# 0  10-23200  Ingeniero de Materiales   MATERIALES   Operativo   NaN
# 1  10-23200  Ingeniero de Materiales   MATERIALES   Operativo   NaN
# 2  10-23200  Ingeniero de Materiales   MATERIALES   Operativo   NaN
# 3  10-24111   Operador de Producción   MATERIALES   Operativo   NaN
# 4  10-24111   Operador de Producción   MATERIALES   Operativo   NaN
#
#    id_empleado    apellido    nombre                             email
# 0          725       Villa   Eliana        eliana .villa@tractchun.com
# 1          747      CHAVEZ  FEDERICO     federico.chavez@tractchun.com
# 2          544    FIGUEROA     ANGEL      angel.figueroa@tractchun.com
# 3         1376  Piedrahita   Gonzalo  gonzalo.piedrahita@tractchun.com
# 4           44    González   Gonzalo    gonzalo.gonzález@tractchun.com

# %%
df['suma'] = df['columna1'] + df['columna2']

# %%
def completo(nombre, apellido):
    df_copia_puestos["nombre_completo"] = (df_copia_puestos["nombre"] + df_copia_puestos["apellido"]) 
    return df_copia_puestos

# %%
df_copia_puestos.apply(lambda dataframe: completo(df_copia_puestos['nombre'], df_copia_puestos['apellido']), axis = 1)
# Out:
# 0            id_puesto                    puesto      ...
# 1            id_puesto                    puesto      ...
# 2            id_puesto                    puesto      ...
# 3            id_puesto                    puesto      ...
# 4            id_puesto                    puesto      ...
#                               ...
# 1995         id_puesto                    puesto      ...
# 1996         id_puesto                    puesto      ...
# 1997         id_puesto                    puesto      ...
# 1998         id_puesto                    puesto      ...
# 1999         id_puesto                    puesto      ...
# Length: 2000, dtype: object

# %%
df_copia_puestos['nombre_completo'].apply (lambda)

datos_personales["Nombre_completo"] = (df_copia_puestos["nombre"] + df_copia_puestos["apellido"]) 

datos_personales
