# %% [markdown]
# - Es el momento de ponernos manos a la obra con la visualización de datos. En este primer ejercicio de pair programming trabajaremos con los csv que generamos en el ejercicio de pair programming de Pandas III, ese en el que habíamos eliminado algunas columnas de nuestro csv.
# Hoy realizaremos una serie de gráficas usando la librería de matplotlib para familiarizarnos un poco con los datos.
#
# 📌 Para poder solucionar los ejercicios de hoy no solo tendremos que visualizar, también tendremos que usar métodos que hemos aprendido en lecciones anteriores de Pandas como por ejemplo value_counts(), isnull, describe, etc.
# Tendréis que realizar gráficas para contestar a las siguientes preguntas:

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_2016 = pd.read_excel("datos/2016_pandasIII.xlsx")
df_2016.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción
# 0           5.0
# 1           5.0
# 2           5.0
# 3           5.0
# 4           5.0

# %% [markdown]
# 1. ¿Cuántos tickets tenemos de cada tipo?
#
# 2. ¿Cuál es el porcentaje de nulos por columna? Usa un pie chart donde incluyáis el porcentaje de cada variable en el interior del quesito. Para eso tendréis que usar el parámetro autopct, aquí algo de documentación.
#
# 3. Filtrad los datos para quedarnos solo con los datos de la categoría "Software".
#
# 4. Dentro del conjunto de datos filtrado que acabamos de generar, realiza la mejor visualización para mostrar cuantos tickets tenemos de cada tipo que tenemos (Problema o Solicitud).
#
# 5. Usando el mismo conjunto de datos filtrado, ¿existe alguna relación entre la satisfacción y los días de resolución?. Poned los nombres de los ejes, siendo el eje x los "días de resolución" y el eje y la "satisfacción".
#
# 6. Usando el mismo conjunto de datos filtrado, ¿cuál es la frecuencia de cada una de las satisfacciones que tenemos en el conjunto de datos?
#
# 7. En el ejercicio anterior hemos filtrado por "Software", realizar los mismos ejercicios que en el ejercicio 3, solo que en este caso filtrar por "Hardware"
#
# 8. Como ya hemos dicho en algunas ocasiones, somo analistas de datos y no debemos conformarnos solo con escribir el código y que nos devuelva una gráfica. Una vez que hayáis terminado de hacer las gráficas, interpretad los resultados obtenidos de las gráficas creadas en el ejercicio 3 y 4. El objetivo, hacer una comparación entre la categoría "Software" y "Hardware", por ejemplo, ¿están los clientes que tienen problemas de la categoría "Software" más satisfechos que los clientes de la categoría "Hardware".

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13051 entries, 0 to 13050
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_ticket        13050 non-null  object
#  1   fecha            13025 non-null  datetime64[ns]
#  2   id_empleado      13049 non-null  float64
#  3   id_agente        13050 non-null  float64
#  4   categoría        13038 non-null  object
#  5   tipo             13050 non-null  object
#  6   severidad        13025 non-null  object
#  7   prioridad        13025 non-null  object
#  8   días_resolución  13049 non-null  float64
#  9   satisfacción     13037 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 1019.7+ KB

# %%
df_2016.describe()
# Out:
#         id_empleado     id_agente  días_resolución  satisfacción
# count  13049.000000  13050.000000     13049.000000  13037.000000
# mean     999.737988     25.425134         4.551843      3.979673
# std      580.422512     14.363362         4.352681      1.326657
# min        1.000000      1.000000         0.000000      1.000000
# 25%      499.000000     13.000000         0.000000      4.000000
# 50%      995.000000     26.000000         4.000000      4.000000
# 75%     1505.000000     38.000000         7.000000      5.000000
# max     2000.000000     50.000000        21.000000      5.000000

# %%
df_2016.head(10)
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# 5  GDLEER-0142608095 2016-08-26         59.0       20.0       Software
# 6  GDLEER-0242564650 2016-07-13       1175.0       36.0       Software
# 7  GDLEER-0542574815 2016-07-23        561.0       18.0       Software
# 8  GDLEER-0842457219 2016-03-28         71.0       12.0       Software
# 9  GDLEER-1242542213 2016-06-21       1831.0       42.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# ...

# %%
# los valores unicos de cada tipo
df_2016['tipo'].value_counts()
# Out:
# Solicitud    9756
# Problema     3294
# Name: tipo, dtype: int64

# %%
#porcentaje de nulos 
porcentaje_nulos = df_2016.isnull().sum()/df_2016.shape[0]*100
porcentaje_nulos
# Out:
# id_ticket          0.007662
# fecha              0.199218
# id_empleado        0.015324
# id_agente          0.007662
# categoría          0.099609
# tipo               0.007662
# severidad          0.199218
# prioridad          0.199218
# días_resolución    0.015324
# satisfacción       0.107271
# dtype: float64

# %%
df_nulos = pd.DataFrame(porcentaje_nulos)
df_nulos
# Out:
#                         0
# id_ticket        0.007662
# fecha            0.199218
# id_empleado      0.015324
# id_agente        0.007662
# categoría        0.099609
# tipo             0.007662
# severidad        0.199218
# prioridad        0.199218
# días_resolución  0.015324
# satisfacción     0.107271

# %%
df_reset = df_nulos.reset_index()
df_reset
# Out:
#              index         0
# 0        id_ticket  0.007662
# 1            fecha  0.199218
# 2      id_empleado  0.015324
# 3        id_agente  0.007662
# 4        categoría  0.099609
# 5             tipo  0.007662
# 6        severidad  0.199218
# 7        prioridad  0.199218
# 8  días_resolución  0.015324
# 9     satisfacción  0.107271

# %%
df_reset.columns
# Out:
# Index(['index', 0], dtype='object')

# %%
# grafico tarta
for col in df_reset.columns[:]:
    plt.figure()
    plt.pie(df_reset[col])
    plt.show()
