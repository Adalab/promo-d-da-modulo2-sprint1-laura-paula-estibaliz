# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/lauramadridsartoretto/Desktop/Adalab/Modulo2/promo-d-da-modulo2-sprint1-laura-paula-estibaliz/Visualizacion'

# %% [markdown]
# Sigamos con más visualizaciones. En este caso trabajaremos con el csv que generamos en el ejercicio de pair programming de Pandas V, ese en el que habíamos unido distintos csv en uno. Al final nos habíamos quedado con los siguientes conjuntos de datos
# - El fichero de la unión de todos los conjuntos de datos de los distintos años
# - El fichero con la unión de los datos de puestos y empleados.
# - El fichero de los agentes.
# 📌 NOTA Os dejamos abajo los ficheros por si no os hubiera dado tiempo a tenerlos preparados

# %%
df_año = pd.read_csv('../datos/historico_tickets.csv', index_col=0)
df_año.head()
# Out:
#            id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453  2016-07-13         1735          4  Acceso&%Login
# 1  GDDENR-8042508060  2016-05-18         1566         10  Acceso&%Login
# 2  GDDESR-1342539995  2016-06-18          569         29        Sistema
# 3  GDDTSR-5942488006  2016-04-28          320         40        Sistema
# 4  GDLEER-0042524120  2016-06-03         1842         31       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar                0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar                0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar                3
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar                9
# 4   Problema          2 - Normal  0 - Sin Asignar                0
#
#    satisfacción     semestre   año
# 0             5  2º semestre  2016
# 1             5   1 semestre  2016
# ...

# %%
df_empleados_puestos = pd.read_csv('../datos/empleados_puestos.csv', index_col=0)
df_empleados_puestos.head()
# Out:
#   Turno  ID Empleado    Apellido    Nombre ID Puesto  \
# 0     A            6       VILLA     JESUS  50-32200
# 1   NaN           60        DIAZ  PATRICIA  50-32200
# 2     B            2      DUARTE   ANTONIO  50-32200
# 3   NaN           24  VILLANUEVA     JESUS  50-32200
# 4   NaN           98    GALLEGOS  PATRICIA  50-32200
#
#                              Email                   Puesto  \
# 0        jesus.villa@tractchun.com  Comprador de Materiales
# 1      patricia.diaz@tractchun.com  Comprador de Materiales
# 2     antonio.duarte@tractchun.com  Comprador de Materiales
# 3   jesus.villanueva@tractchun.com  Comprador de Materiales
# 4  patricia.gallegos@tractchun.com  Comprador de Materiales
#
#             Departamento     Tipo Puesto
# 0  CONTROL DE PRODUCCION  Administrativo
# 1  CONTROL DE PRODUCCION  Administrativo
# 2  CONTROL DE PRODUCCION  Administrativo
# 3  CONTROL DE PRODUCCION  Administrativo
# 4  CONTROL DE PRODUCCION  Administrativo

# %%
df_agentes = pd.read_csv('../datos/Agentes.csv', index_col=0)
df_agentes.head()
# Out:
#                         Nombre                              email  \
# ID Agente
# 1                  Mata Lucero          lucero.mata@tractchun.com
# 2                 JesusGrajeda        jesus.grajeda@tractchun.com
# 3                  Elena Velez          elena.velez@tractchun.com
# 4              Barraza Alberto      alberto.barraza@tractchun.com
# 5          Willyberto Gonzales  willyberto.gonzales@tractchun.com
#
#           Fecha de Nacimiento
# ID Agente
# 1                   1989/4/28
# 2                    1979/1/1
# 3                    1993/6/6
# 4                  1978/10/20
# 5                   1973/5/11

# %% [markdown]
# Las preguntas que tendréis que contestar son:
#
# Ayer creamos un par de gráficas para los tickets de la categoría "Software" y "Hardware", donde visualizamos el número de clientes que teníamos en cada grupo de satisfacción. Hoy tendréis que hacer dos gráficas con subplots:
# En la primera debéis mostrar la cantidad de tickets en función del tipo (si es Problema o Solicitud), cada subplot corresponderá a cada una de las categorías. Debéis:
#
# 1. Poner nombre a los ejes de cada uno de los subplots
# 2. Poner un títulos a cada uno de los subplots
# 3. Poner el color de las líneas en negro.
# 3. Establecer el tamaño de la gráfica a 15 x 5
# 4. Ponerle marcadores a las gráficas. No incluir leyenda

# %%
df_soft = df_año[(df_año["categoría"] == "Software")]
df_soft
# Out:
#                id_ticket       fecha  id_empleado  id_agente categoría  \
# 4      GDLEER-0042524120  2016-06-03         1842         31  Software
# 5      GDLEER-0142608095  2016-08-26           59         20  Software
# 6      GDLEER-0242564650  2016-07-13         1175         36  Software
# 7      GDLEER-0542574815  2016-07-23          561         18  Software
# 8      GDLEER-0842457219  2016-03-28           71         12  Software
# ...                  ...         ...          ...        ...       ...
# 29051  TWRTER-0144168565  2020-12-03         1806          5  Software
# 29052  TWRTER-0344087411  2020-09-13         1251         44  Software
# 29057  TWRTER-3244083018  2020-09-09          641         20  Software
# 29058  TWRTER-4843876490  2020-02-15          759         24  Software
# 29060  TWRTER-8044045914  2020-08-02           51          9  Software
#
#             tipo   severidad        prioridad  días_resolución  satisfacción  \
# ...

# %%
df_hard = df_año[(df_año["categoría"] == "Hardware")]
df_hard
# Out:
#                id_ticket       fecha  id_empleado  id_agente categoría  \
# 15     GDLEER-2342731423  2016-12-27          422         24  Hardware
# 18     GDLEER-3042628638  2016-09-15         1863         46  Hardware
# 25     GDLEER-3542665966  2016-10-22         1996         29  Hardware
# 27     GDLEER-3742656857  2016-10-13         1025         18  Hardware
# 28     GDLEER-4042683896  2016-11-09         1469         38  Hardware
# ...                  ...         ...          ...        ...       ...
# 29054  TWRTER-2344005846  2020-06-23          334         18  Hardware
# 29055  TWRTER-2944119419  2020-10-15          761         14  Hardware
# 29056  TWRTER-3043884617  2020-02-23          611         36  Hardware
# 29059  TWRTER-4943876231  2020-02-15         1093         32  Hardware
# 29061  TWRTET-4544082371  2020-09-08         1617         33  Hardware
#
#             tipo   severidad        prioridad  días_resolución  satisfacción  \
# ...

# %%
df_cat_soft = pd.read_csv("../datos/cat_soft.csv", index_col=0)
df_cat_soft.head()
# Out:
#        index  tipo
# 0  Solicitud  1948
# 1   Problema   664

# %%
df_cat_hard = pd.read_csv("../datos/cat_hard.csv", index_col=0)
df_cat_hard.head()
# Out:
#        index  tipo
# 0  Solicitud   956
# 1   Problema   315

# %%
fig,ax = plt.subplots(1,2, figsize = (15, 5))

ax[0].plot(df_cat_soft['index'], df_cat_soft['tipo'], marker = "^", color = "blue")
ax[1].plot(df_cat_hard['index'], df_cat_hard['tipo'], marker = "^", color = "green")

ax[0].set_xlabel("tipo")
ax[1].set_xlabel("tipo")

ax[0].set_ylabel("cantidad de tickets")
ax[1].set_ylabel("cantidad de tickets")

ax[0].set_title("software")
ax[1].set_title("hardware")


plt.show()

# %%
plt.savefig("../datos/tickets_por_tipo.png")

# %% [markdown]
#  En la segunda debéis mostrar el número de tickets en función de la satisfacción.
#
#   1. De nuevo tendréis que ponerle nombre a los ejes y título a cada gráfica.
#   2. En este caso el subplot deberá tener dos filas y una columna
#   3. No incluir leyenda
#   4. Cambiar el color de las barras

# %%
df_hard.head()
# Out:
#             id_ticket       fecha  id_empleado  id_agente categoría      tipo  \
# 15  GDLEER-2342731423  2016-12-27          422         24  Hardware  Problema
# 18  GDLEER-3042628638  2016-09-15         1863         46  Hardware  Problema
# 25  GDLEER-3542665966  2016-10-22         1996         29  Hardware  Problema
# 27  GDLEER-3742656857  2016-10-13         1025         18  Hardware  Problema
# 28  GDLEER-4042683896  2016-11-09         1469         38  Hardware  Problema
#
#      severidad        prioridad  días_resolución  satisfacción     semestre  \
# 15  2 - Normal  0 - Sin Asignar               10             5  2º semestre
# 18  2 - Normal  0 - Sin Asignar                9             5  2º semestre
# 25  2 - Normal  0 - Sin Asignar                5             5  2º semestre
# 27  2 - Normal  0 - Sin Asignar                7             5  2º semestre
# 28  2 - Normal  0 - Sin Asignar               13             5  2º semestre
#
#      año
# 15  2016
# 18  2016
# ...

# %%
sats_hard =df_hard["satisfacción"].value_counts().reset_index()
sats_hard

sats_hard.sort_values(by= "index")
# Out:
#    index  satisfacción
# 2      1          1000
# 4      2           185
# 3      3           744
# 1      4          2687
# 0      5          5101

# %%
df_soft.head()
# Out:
#            id_ticket       fecha  id_empleado  id_agente categoría      tipo  \
# 4  GDLEER-0042524120  2016-06-03         1842         31  Software  Problema
# 5  GDLEER-0142608095  2016-08-26           59         20  Software  Problema
# 6  GDLEER-0242564650  2016-07-13         1175         36  Software  Problema
# 7  GDLEER-0542574815  2016-07-23          561         18  Software  Problema
# 8  GDLEER-0842457219  2016-03-28           71         12  Software  Problema
#
#     severidad        prioridad  días_resolución  satisfacción     semestre  \
# 4  2 - Normal  0 - Sin Asignar                0             5   1 semestre
# 5  2 - Normal  0 - Sin Asignar                1             1  2º semestre
# 6  2 - Normal  0 - Sin Asignar                2             1  2º semestre
# 7  2 - Normal  0 - Sin Asignar                5             5  2º semestre
# 8  2 - Normal  0 - Sin Asignar                8             5   1 semestre
#
#     año
# 4  2016
# 5  2016
# 6  2016
# 7  2016
# ...

# %%
sats_soft =df_soft["satisfacción"].value_counts().reset_index()
sats_soft

sats_soft.sort_values(by= "index")
# Out:
#    index  satisfacción
# 2      1          1969
# 4      2           388
# 3      3          1465
# 1      4          5485
# 0      5         10236

# %%
fig,ax = plt.subplots(1,2, figsize = (15, 5))

ax[0].bar(sats_hard['index'], sats_hard['satisfacción'], color = "green")
ax[1].bar(sats_soft['index'], sats_soft['satisfacción'], color = "blue")

ax[0].set_xlabel("satisfacción")
ax[1].set_xlabel("satisfacción")

ax[0].set_ylabel("cantidad de tickets")
ax[1].set_ylabel("cantidad de tickets")

ax[0].set_title("software")
ax[1].set_title("hardware")
# Out:
# Text(0.5, 1.0, 'hardware')
