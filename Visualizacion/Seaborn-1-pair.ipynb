# %% [markdown]
# En este ejercicio, de nuevo, trabajaremos con el csv que generamos en el ejercicio de pair programming de Pandas V, ese en el que habíamos unido distintos csv en uno.
#
# - En estos ejercicios aprenderemos a hacer algunas gráficas usando la librería seaborn. Igual que el ejercicio anterior de pair programming, para solucionar algunas preguntas tendréis que usar métodos y herramientas aprendidas anteriormente como groupby, value_counts, rename, filtrado de datos, etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df_años = pd.read_csv('../datos/años.csv', index_col=0) 
df_años.head()
# Out:
#            id_ticket       fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453  2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060  2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995  2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006  2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120  2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción   año
# 0           5.0  2016
# 1           5.0  2016
# 2           5.0  2016
# 3           5.0  2016
# 4           5.0  2016

# %% [markdown]
# 1. Nuestro Usando la librería seaborn, cread una gráfica que nos muestre el número de personas que han hecho una solicitud de ticket en cada año. Hacedlo solo para los del tipo "Problema".

# %%
df_años['fecha'] = df_años['fecha'].apply(pd.to_datetime)

# %%
def sacar_año(x):
    try:
        return x.strftime('%Y')
    except:
        return x

# %%
df_años['año'] = df_años['fecha'].apply(sacar_año)
df_años.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción   año
# 0           5.0  2016
# 1           5.0  2016
# 2           5.0  2016
# 3           5.0  2016
# 4           5.0  2016

# %%
df_problema = df_años[df_años['tipo'] == 'Problema']
df_problema.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# 5  GDLEER-0142608095 2016-08-26         59.0       20.0       Software
#
#        tipo           severidad        prioridad  días_resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 4  Problema          2 - Normal  0 - Sin Asignar              0.0
# 5  Problema          2 - Normal  0 - Sin Asignar              1.0
#
#    satisfacción   año
# 0           5.0  2016
# 1           5.0  2016
# 2           5.0  2016
# 4           5.0  2016
# 5           1.0  2016

# %%
plt.figure()
fig = sns.countplot(x='año', data= df_problema)
plt.show()

# %% [markdown]
# 2. La gráfica anterior nos ha mostrado una tendencia ascendente en el número de solicitudes a lo largo de los años, lo que preocupa a la empresa, por lo que quieres seguir analizando los datos para ver si son capaces de identificar los problemas subyacentes a estas solicitudes. Para esto, quieren saber si hay diferencias a lo largo del año. En concreto nos piden que hagamos un subplot con seaborn donde:
#
# - En la primera gráfica tengamos la gráfica que creamos en el ejercicio anterior
# - En la segunda gráfica tengamos la comparación por años y sementres para el número de tikects de tipo "Problema".

# %%
df_años['fecha'].dt.month

# %%
condic = df_años['fecha'].dt.month < 7
df_años['semestre'] = np.where(condic, '1er semestre', '2º semestre')
df_años.sample(5)

# aplicamos la condicion a todo el dataframe completo
# Out:
#                id_ticket      fecha  id_empleado  id_agente      categoría  \
# 2891   GMLTNR-8042623356 2016-09-10        895.0       23.0  Acceso&%Login
# 13010  SDLTNR-1143485048 2019-01-20       1034.0       30.0  Acceso99Login
# 14956  SHLTSR-4143495186 2019-01-30       1308.0       41.0        Sistema
# 21299  TWLTSR-3943742246 2019-10-04       1294.0       42.0        Sistema
# 17724  TMLEER-9343173022 2018-03-14       1892.0       30.0       Hardware
#
#             tipo   severidad        prioridad  días_resolución  satisfacción  \
# 2891   Solicitud  2 - Normal        2 - Media              0.0           5.0
# 13010  Solicitud  2 - Normal  0 - Sin Asignar              1.0           4.0
# 14956  Solicitud  2 - Normal         3 - Alta              2.0           4.0
# 21299  Solicitud  2 - Normal         1 - Baja              9.0           4.0
# 17724   Problema  2 - Normal        2 - Media              3.0           5.0
#
#         año      semestre
# 2891   2016   2º semestre
# 13010  2019  1er semestre
# 14956  2019  1er semestre
# 21299  2019   2º semestre
# 17724  2018  1er semestre

# %%
df_prob_semestre = df_años[df_años['tipo'] == 'Problema']
df_prob_semestre.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# 5  GDLEER-0142608095 2016-08-26         59.0       20.0       Software
#
#        tipo           severidad        prioridad  días_resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 4  Problema          2 - Normal  0 - Sin Asignar              0.0
# 5  Problema          2 - Normal  0 - Sin Asignar              1.0
#
#    satisfacción   año      semestre
# 0           5.0  2016   2º semestre
# 1           5.0  2016  1er semestre
# 2           5.0  2016  1er semestre
# 4           5.0  2016  1er semestre
# 5           1.0  2016   2º semestre

# %%
fig, axes = plt.subplots(1,2, figsize=(20, 10))

sns.countplot(x='año', data=df_prob_semestre, ax=axes[0])

sns.countplot(x='año', data=df_prob_semestre, ax=axes[1], hue='semestre')

plt.show()

# %% [markdown]
# 3. La empresa se siente algo aliviada al ver que no hay diferencias entre semestres, pero seguimos sin identificar porque cada año tenemos más solicitudes. Nuestras jefas quieren saber ahora, que prioridad tienen los tickets que tenemos en el conjunto de datos. Por eso nos piden que volvamos a hacer un subplot:
#
# - En la primera gráfica deberíamos tener la gráfica creada en el ejercicio 1
# - En la segunda gráfica deberíamos incluir el número de tickets por año en función de la prioridad que tienen.

# %%
fig, axes = plt.subplots(1,2, figsize=(20, 10))

sns.countplot(x='año', data=df_prob_semestre, ax=axes[0])
sns.countplot(x='año', data=df_prob_semestre, ax=axes[1], hue='prioridad')

plt.show()

# %% [markdown]
# 4. Hasta ahora hemos estado viendo que no parece que haya nada alarmante. Por lo que ahora quieren que evaluemos la cantidad de trabajo que cada empleado esta haciendo, para poder identificar rápidamente un problema en la distribución de tareas y tomar medidas para solucionarlo. Para ello nos piden que hagamos dos gráficas en un subplot:
# - La primera gráfica tiene que tener los 5 empleados con mayor número de tickets, deberemos mostrar quienes son y cuál es total de tickets que atienden cada uno.
# - La primera gráfica tiene que tener los 5 empleados con menor número de tickets, deberemos mostrar quienes son y cuál es total de tickets que atienden cada uno.

# %%
df_prob_semestre.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# 5  GDLEER-0142608095 2016-08-26         59.0       20.0       Software
#
#        tipo           severidad        prioridad  días_resolución  \
# 0  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1  Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2  Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 4  Problema          2 - Normal  0 - Sin Asignar              0.0
# 5  Problema          2 - Normal  0 - Sin Asignar              1.0
#
#    satisfacción   año      semestre
# 0           5.0  2016   2º semestre
# 1           5.0  2016  1er semestre
# 2           5.0  2016  1er semestre
# 4           5.0  2016  1er semestre
# 5           1.0  2016   2º semestre

# %%
fig, axes = plt.subplots(1,2, figsize=(20, 10))

sns.countplot(x='id_empleado', data=df_prob_semestre, order=df_prob_semestre['id_empleado'].value_counts().iloc[:5].index, ax=axes[0])
sns.countplot(x='id_empleado', data=df_prob_semestre, order=df_prob_semestre['id_empleado'].value_counts().iloc[-5:].index, ax=axes[1])

axes[0].set_title('Empleados con mayor número de tickets') 
axes[1].set_title('Empleados con menor número de tickets') 

plt.show()
