# %% [markdown]
# - Es el momento de ponernos manos a la obra con la visualización de datos. En este primer ejercicio de pair programming trabajaremos con los csv que generamos en el ejercicio de pair programming de Pandas III, ese en el que habíamos eliminado algunas columnas de nuestro csv.
# Hoy realizaremos una serie de gráficas usando la librería de matplotlib para familiarizarnos un poco con los datos.
#
# 📌 Para poder solucionar los ejercicios de hoy no solo tendremos que visualizar, también tendremos que usar métodos que hemos aprendido en lecciones anteriores de Pandas como por ejemplo value_counts(), isnull, describe, etc.
# Tendréis que realizar gráficas para contestar a las siguientes preguntas:

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#abrimos el fichero con el dataset df_2016

df_2016 = pd.read_excel("datos/2016_pandasIII.xlsx")
df_2016.head()
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 1   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# 2   Problema  0 - Sin Clasificar  0 - Sin Asignar              3.0
# 3  Solicitud  0 - Sin Clasificar  0 - Sin Asignar              9.0
# 4   Problema          2 - Normal  0 - Sin Asignar              0.0
#
#    satisfacción
# 0           5.0
# 1           5.0
# 2           5.0
# 3           5.0
# 4           5.0

# %% [markdown]
# 1. ¿Cuántos tickets tenemos de cada tipo?

# %%
# exploracion del df_2016

df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13051 entries, 0 to 13050
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_ticket        13050 non-null  object
#  1   fecha            13025 non-null  datetime64[ns]
#  2   id_empleado      13049 non-null  float64
#  3   id_agente        13050 non-null  float64
#  4   categoría        13038 non-null  object
#  5   tipo             13050 non-null  object
#  6   severidad        13025 non-null  object
#  7   prioridad        13025 non-null  object
#  8   días_resolución  13049 non-null  float64
#  9   satisfacción     13037 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 1019.7+ KB

# %%
# extraímos los valores unicos de cada tipo

df_valores = df_2016['tipo'].value_counts().reset_index()
df_valores
# Out:
#        index  tipo
# 0  Solicitud  9756
# 1   Problema  3294

# %%
# elaboramos la gráfica de barras con los valores únicos de solicitud y problema

plt.figure()
plt.bar(df_valores["index"], df_valores["tipo"])
plt.show()

# %%
# exploramos df_2016

df_2016.head(10)
# Out:
#            id_ticket      fecha  id_empleado  id_agente      categoría  \
# 0  GDDENR-5042564453 2016-07-13       1735.0        4.0  Acceso&%Login
# 1  GDDENR-8042508060 2016-05-18       1566.0       10.0  Acceso&%Login
# 2  GDDESR-1342539995 2016-06-18        569.0       29.0        Sistema
# 3  GDDTSR-5942488006 2016-04-28        320.0       40.0        Sistema
# 4  GDLEER-0042524120 2016-06-03       1842.0       31.0       Software
# 5  GDLEER-0142608095 2016-08-26         59.0       20.0       Software
# 6  GDLEER-0242564650 2016-07-13       1175.0       36.0       Software
# 7  GDLEER-0542574815 2016-07-23        561.0       18.0       Software
# 8  GDLEER-0842457219 2016-03-28         71.0       12.0       Software
# 9  GDLEER-1242542213 2016-06-21       1831.0       42.0       Software
#
#         tipo           severidad        prioridad  días_resolución  \
# 0   Problema  0 - Sin Clasificar  0 - Sin Asignar              0.0
# ...

# %% [markdown]
# 2. Filtrad los datos para quedarnos solo con los datos de la categoría "Software".

# %%
# extraimos solo los datos de la categoría software

categoría_soft = df_2016[df_2016["categoría"] == 'Software']
categoría_soft
# Out:
#                id_ticket      fecha  id_empleado  id_agente categoría  \
# 4      GDLEER-0042524120 2016-06-03       1842.0       31.0  Software
# 5      GDLEER-0142608095 2016-08-26         59.0       20.0  Software
# 6      GDLEER-0242564650 2016-07-13       1175.0       36.0  Software
# 7      GDLEER-0542574815 2016-07-23        561.0       18.0  Software
# 8      GDLEER-0842457219 2016-03-28         71.0       12.0  Software
# ...                  ...        ...          ...        ...       ...
# 13020  TWREER-3542682716 2016-11-08        411.0       37.0  Software
# 13022  TWREER-4142552705 2016-07-01       1680.0       27.0  Software
# 13034  TWRTER-2042528927 2016-06-07        462.0       19.0  Software
# 13036  TWRTER-8742418826 2016-02-18        942.0       28.0  Software
# 13037  TWRTER-9542402645 2016-02-02        334.0       26.0  Software
#
#             tipo   severidad        prioridad  días_resolución  satisfacción
# ...

# %%
# extraimos solo los datos de la categoría hardware

categoría_hard = df_2016[df_2016["categoría"] == 'Hardware']
categoría_hard
# Out:
#                id_ticket      fecha  id_empleado  id_agente categoría  \
# 15     GDLEER-2342731423 2016-12-27        422.0       24.0  Hardware
# 18     GDLEER-3042628638 2016-09-15       1863.0       46.0  Hardware
# 25     GDLEER-3542665966 2016-10-22       1996.0       29.0  Hardware
# 27     GDLEER-3742656857 2016-10-13       1025.0       18.0  Hardware
# 28     GDLEER-4042683896 2016-11-09       1469.0       38.0  Hardware
# ...                  ...        ...          ...        ...       ...
# 12799  TWLTER-9942724654 2016-12-20       1245.0       16.0  Hardware
# 12802  TWLTET-8342499857 2016-05-09       1045.0       28.0  Hardware
# 13021  TWREER-4142462018 2016-04-02        111.0       30.0  Hardware
# 13035  TWRTER-5042710887 2016-12-06       1098.0       38.0  Hardware
# 13038  TWRTER-9642514691 2016-05-24        909.0       16.0  Hardware
#
#             tipo   severidad        prioridad  días_resolución  satisfacción
# ...

# %% [markdown]
#
#    2.1 Dentro del conjunto de datos filtrado que acabamos de generar, realiza la mejor visualización para mostrar cuantos tickets tenemos de cada tipo que tenemos (Problema o Solicitud).

# %%
# extraimos los datos de cada tipo de ticket (problema y solicitud)

df_count_soft = pd.DataFrame(categoría_soft["tipo"].value_counts())
df_count_soft.reset_index(inplace=True)


df_count_soft
# Out:
#        index  tipo
# 0  Solicitud  1948
# 1   Problema   664

# %%
# creamos el índice del df con el método reset.index()

df_count_hard = pd.DataFrame(categoría_hard["tipo"].value_counts())
df_count_hard.reset_index(inplace=True)
df_count_hard
# Out:
#        index  tipo
# 0  Solicitud   956
# 1   Problema   315

# %%
# creamos la gráfica de tipos para cada ticket (problema y solicitud) de la cateforía software 

plt.figure()
plt.bar(df_count_soft["index"], df_count_soft["tipo"])
plt.show()

# %%
# creamos la gráfica de tipos para cada ticket (problema y solicitud) de la cateforía hardware

plt.figure()
plt.bar(df_count_hard["index"], df_count_hard["tipo"])
plt.show()

# %% [markdown]
# Las solicitudes para software son mas que el doble de las solicitudes para hardware. La variable problema se porta de la misma forma.

# %% [markdown]
#   2.2 Usando el mismo conjunto de datos filtrado, ¿existe alguna relación entre la satisfacción y los días de resolución?. Poned los nombres de los ejes, siendo el eje x los "días de resolución" y el eje y la "satisfacción".

# %%
categoría_soft
# Out:
#                id_ticket      fecha  id_empleado  id_agente categoría  \
# 4      GDLEER-0042524120 2016-06-03       1842.0       31.0  Software
# 5      GDLEER-0142608095 2016-08-26         59.0       20.0  Software
# 6      GDLEER-0242564650 2016-07-13       1175.0       36.0  Software
# 7      GDLEER-0542574815 2016-07-23        561.0       18.0  Software
# 8      GDLEER-0842457219 2016-03-28         71.0       12.0  Software
# ...                  ...        ...          ...        ...       ...
# 13020  TWREER-3542682716 2016-11-08        411.0       37.0  Software
# 13022  TWREER-4142552705 2016-07-01       1680.0       27.0  Software
# 13034  TWRTER-2042528927 2016-06-07        462.0       19.0  Software
# 13036  TWRTER-8742418826 2016-02-18        942.0       28.0  Software
# 13037  TWRTER-9542402645 2016-02-02        334.0       26.0  Software
#
#             tipo   severidad        prioridad  días_resolución  satisfacción
# ...

# %%
categoría_hard
# Out:
#                id_ticket      fecha  id_empleado  id_agente categoría  \
# 15     GDLEER-2342731423 2016-12-27        422.0       24.0  Hardware
# 18     GDLEER-3042628638 2016-09-15       1863.0       46.0  Hardware
# 25     GDLEER-3542665966 2016-10-22       1996.0       29.0  Hardware
# 27     GDLEER-3742656857 2016-10-13       1025.0       18.0  Hardware
# 28     GDLEER-4042683896 2016-11-09       1469.0       38.0  Hardware
# ...                  ...        ...          ...        ...       ...
# 12799  TWLTER-9942724654 2016-12-20       1245.0       16.0  Hardware
# 12802  TWLTET-8342499857 2016-05-09       1045.0       28.0  Hardware
# 13021  TWREER-4142462018 2016-04-02        111.0       30.0  Hardware
# 13035  TWRTER-5042710887 2016-12-06       1098.0       38.0  Hardware
# 13038  TWRTER-9642514691 2016-05-24        909.0       16.0  Hardware
#
#             tipo   severidad        prioridad  días_resolución  satisfacción
# ...

# %%
# creamos la gráfica de satisfacción por días_resolucíon para la categoría software

plt.figure(figsize = (10,5))

plt.hist(categoría_soft["satisfacción"], color = "green")

plt.xlabel("días_resolución")

plt.ylabel("satisfacción")

plt.title("satisfacción_días_resolución")

plt.grid(color = "grey", linestyle = "-.")

plt.show()

# %%
# creamos la gráfica de satisfacción por días_resolucíon para la categoría hardware

plt.figure(figsize = (10,5))

plt.hist(categoría_hard["satisfacción"], color = "green")

plt.xlabel("días_resolución")

plt.ylabel("satisfacción")

plt.title("satisfacción_días_resolución")

plt.grid(color = "grey", linestyle = "-.")

plt.show()

# %% [markdown]
# - Se puede notar que en general, para las dos categorías, cuanto más dias de resolucion (hasta 5 días) mas satisfechos están los clientes.
# - En ambos los casos, los clientes cuyos tickets tardan 2 días para la resolucion no suelen estar satisfechos.

# %% [markdown]
# 2.3 Usando el mismo conjunto de datos filtrado, ¿cuál es la frecuencia de cada una de las satisfacciones que tenemos en el conjunto de datos?

# %%
plt.figure()

plt.hist(x = categoría_soft["satisfacción"], facecolor  = 'green', edgecolor = "black" )

plt.show()

# %%
plt.figure()

plt.hist(x = categoría_hard["satisfacción"], facecolor  = 'green', edgecolor = "black" )

plt.show()

# %% [markdown]
# La frencuencia de satisfacción con la atencion es similar para software y hardware
